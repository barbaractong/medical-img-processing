# %% [markdown]
# Hi Barbara.  I think you tried to do equalisation of the histogram in the  previous example.
#
# OK.
# You have an image of 80x80 = 6400 pixels. You can create two regions of any shape you want, but they have to be 2000 and 3000 pixels respectively.  This will overwrite the original 6400 pixels.  So you will have
#
# Region 1- pixels of value 20 (I am not looking at the problem, but I think it is 20) = 6400 - 2000 - 3000
# Region 2- Pixels of value (your choice), say 100.  2000 pixels.
# Region 3- pixels of your choice, say 220. 3000 pixels.
#
# So the histogram would be
# 1400 pixels with gray value 20
# 2000 pixels with gray value 100
# 3000 pixels with gray value 220.
#
# Now you have to make a table, and calculate the quantities (probability, CDF, mean, variance, etc.)
# Probabilities will be:
# 1400/6400 for pixels of gray value 20,
# etc.
#
# I don't want to do the problem for you!
#
# At the end of your calculations you know how to transform each gray level pixel in your original image to a new gray level.  This is what we are trying to find in histogram equalisation. Any pixel with value 20 will go to value ? in the new image.
#
# We can talk about this if you don't understand and I'll give you an extension.  But it isn't very difficult.  YOu can create a spreadsheet (planilha) with this information - it is easy to do in a spreadsheet with formulae.

# %%
import numpy as np

import imageio
import cv2 as openCV
from PIL import Image, ImageOps

import matplotlib.pyplot as plt

# %%
bits = 256
sizeMatrix = 80

data = np.zeros((sizeMatrix, sizeMatrix, 3), dtype=np.uint8)

data[5:30, 5:30] = [20,20,20] # red patch in upper left

plt.imshow(data)
